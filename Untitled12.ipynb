# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df= pd.read_csv("C:/Users/PC/Documents/PBJ_Daily_Nurse_Staffing_Q2_2024.csv", encoding="ISO-8859-1",dtype={"PROVNUM": str})
df
# Out:
#         PROVNUM                       PROVNAME          CITY STATE  \
# 0         15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 1         15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 2         15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 3         15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 4         15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# ...         ...                            ...           ...   ...
# 1325319  745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325320  745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325321  745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325322  745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325323  745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
#
#         COUNTY_NAME  COUNTY_FIPS  CY_Qtr    WorkDate  MDScensus  Hrs_RNDON  \
# 0          Franklin           59  2024Q2  2024-04-01         51      10.77
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['PROVNUM', 'PROVNAME', 'CITY', 'STATE', 'COUNTY_NAME', 'COUNTY_FIPS', 'CY_Qtr', 'WorkDate', 'MDScensus', 'Hrs_RNDON', 'Hrs_RNDON_emp', 'Hrs_RNDON_ctr', 'Hrs_RNadmin', 'Hrs_RNadmin_emp', 'Hrs_RNadmin_ctr', 'Hrs_RN', 'Hrs_RN_emp', 'Hrs_RN_ctr', 'Hrs_LPNadmin', 'Hrs_LPNadmin_emp', 'Hrs_LPNadmin_ctr', 'Hrs_LPN', 'Hrs_LPN_emp', 'Hrs_LPN_ctr', 'Hrs_CNA', 'Hrs_CNA_emp', 'Hrs_CNA_ctr', 'Hrs_NAtrn', 'Hrs_NAtrn_emp', 'Hrs_NAtrn_ctr', 'Hrs_MedAide', 'Hrs_MedAide_emp', 'Hrs_MedAide_ctr']

# %%
df=df.drop(df.columns[[9,12,15,18,21,24,27,30]],axis=1)#drops the non ctr, emp
zero_percentage = (df == 0).sum() / len(df) * 100
zero_percentage_sorted = zero_percentage.sort_values(ascending=True)

# Plot horizontal bar chart
plt.figure(figsize=(8, 5))
plt.barh(zero_percentage_sorted.index, zero_percentage_sorted.values, color='skyblue')

# Labels and title
plt.ylabel("Columns")
plt.xlabel("Percentage of Zeros")
plt.title("Percentage of Zeros in Each Column (Decreasing Order)")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as mticker

# Get column names and their sums
column_sums = df.iloc[:, 9:].sum()

# Sort in descending order
column_sums_sorted = column_sums.sort_values(ascending=True)

# Extract sorted names and values
column_names_sorted = column_sums_sorted.index
column_values_sorted = column_sums_sorted.values

# Plot
plt.figure(figsize=(8, 5))
plt.barh(column_names_sorted, column_values_sorted, color='skyblue')
plt.xlabel("Columns")
plt.ylabel("Sum")
plt.title("Sum of Selected Columns (Sorted)")

# Format x-axis to show full numbers
ax = plt.gca()
formatter = mticker.ScalarFormatter(useOffset=False)
formatter.set_scientific(False)
ax.xaxis.set_major_formatter(formatter)

plt.xticks(rotation=90)
plt.show()

# %%
# Disable scientific notation for large numbers
pd.set_option('display.float_format', '{:.4f}'.format)
column_sums_df = pd.DataFrame(df.iloc[:, 9:].sum())  # Transpose to keep it as a row
column_sums_df
# Out:
#                               0
# Hrs_RNDON          6886233.6000
# Hrs_RNDON_emp      6758241.1300
# Hrs_RNDON_ctr       127992.4700
# Hrs_RNadmin       13601474.4000
# Hrs_RNadmin_emp   13268669.3300
# Hrs_RNadmin_ctr     332805.0700
# Hrs_RN            46123818.5300
# Hrs_RN_emp        42397419.6400
# Hrs_RN_ctr         3726398.8900
# Hrs_LPNadmin       8896195.8400
# Hrs_LPNadmin_emp   8806224.2700
# Hrs_LPNadmin_ctr     89971.5700
# Hrs_LPN           87699900.5600
# Hrs_LPN_emp       79571106.8600
# Hrs_LPN_ctr        8128793.7000
# Hrs_CNA          230329065.6300
# Hrs_CNA_emp      214184634.7200
# Hrs_CNA_ctr       16144430.9100
# Hrs_NAtrn          5717653.2100
# Hrs_NAtrn_emp      5648619.5400
# Hrs_NAtrn_ctr        69033.6700
# Hrs_MedAide       11369062.0900
# Hrs_MedAide_emp   11084086.6700
# Hrs_MedAide_ctr     284975.4200

# %%
# Convert the 'workday' column from YYYYMMDD to a proper date format
df['WorkDate'] = pd.to_datetime(df['WorkDate'], format='%Y%m%d') 
df['PROVNUM'] = pd.to_numeric(df['PROVNUM'], errors='coerce').fillna(0).astype(int)
df.to_csv('PBJ_Daily_Nurse_Staffing_Q2_2024.csv', index=False)# Show the DataFrame
df
# Out:
#          PROVNUM                       PROVNAME          CITY STATE  \
# 0          15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 1          15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 2          15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 3          15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# 4          15009       BURNS NURSING HOME, INC.  RUSSELLVILLE    AL
# ...          ...                            ...           ...   ...
# 1325319   745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325320   745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325321   745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325322   745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
# 1325323   745040  THE SARAH ROBERTS FRENCH HOME   SAN ANTONIO    TX
#
#         COUNTY_NAME  COUNTY_FIPS  CY_Qtr   WorkDate  MDScensus  Hrs_RNDON  \
# 0          Franklin           59  2024Q2 2024-04-01         51    10.7700
# ...

# %%
import os

# Get current working directory
print(os.getcwd())
# Out:
# C:\Users\PC

# %%
column_sums_df = pd.DataFrame(df.iloc[:, 9:].sum())
column_sums_df = column_sums_df.rename(columns={0: "Sum"})  # Rename unnamed column
column_sums_sorted = column_sums_df.sort_values(by="Sum", ascending=False)
column_sums_sorted
# Out:
#                             Sum
# Hrs_CNA          230329065.6300
# Hrs_CNA_emp      214184634.7200
# Hrs_LPN           87699900.5600
# Hrs_LPN_emp       79571106.8600
# Hrs_RN            46123818.5300
# Hrs_RN_emp        42397419.6400
# Hrs_CNA_ctr       16144430.9100
# Hrs_RNadmin       13601474.4000
# Hrs_RNadmin_emp   13268669.3300
# Hrs_MedAide       11369062.0900
# Hrs_MedAide_emp   11084086.6700
# Hrs_LPNadmin       8896195.8400
# Hrs_LPNadmin_emp   8806224.2700
# Hrs_LPN_ctr        8128793.7000
# Hrs_RNDON          6886233.6000
# Hrs_RNDON_emp      6758241.1300
# Hrs_NAtrn          5717653.2100
# Hrs_NAtrn_emp      5648619.5400
# Hrs_RN_ctr         3726398.8900
# Hrs_RNadmin_ctr     332805.0700
# Hrs_MedAide_ctr     284975.4200
# Hrs_RNDON_ctr       127992.4700
# Hrs_LPNadmin_ctr     89971.5700
# Hrs_NAtrn_ctr        69033.6700

# %%
column_sums_df = pd.DataFrame(df.iloc[:, 9:].sum()).T  # Transpose to keep it as a row

column_sums_df.to_csv('column_sums_df_PBJ_Daily_Nurse_Staffing_Q2_2024.csv', index=False)# Show the DataFrame
column_sums_df
# Out:
#      Hrs_RNDON  Hrs_RNDON_emp  Hrs_RNDON_ctr   Hrs_RNadmin  Hrs_RNadmin_emp  \
# 0 6886233.6000   6758241.1300    127992.4700 13601474.4000    13268669.3300
#
#    Hrs_RNadmin_ctr        Hrs_RN    Hrs_RN_emp   Hrs_RN_ctr  Hrs_LPNadmin  \
# 0      332805.0700 46123818.5300 42397419.6400 3726398.8900  8896195.8400
#
#    ...  Hrs_LPN_ctr        Hrs_CNA    Hrs_CNA_emp   Hrs_CNA_ctr    Hrs_NAtrn  \
# 0  ... 8128793.7000 230329065.6300 214184634.7200 16144430.9100 5717653.2100
#
#    Hrs_NAtrn_emp  Hrs_NAtrn_ctr   Hrs_MedAide  Hrs_MedAide_emp  \
# 0   5648619.5400     69033.6700 11369062.0900    11084086.6700
#
#    Hrs_MedAide_ctr
# 0      284975.4200
#
# [1 rows x 24 columns]

# %%
zero_counts = (df == 0).sum()  # Count zeros in each column
column_with_most_zeros = zero_counts.idxmax()  # Get the column name with max zeros
max_zeros = zero_counts.max()  # Get the max count of zeros


zero_counts_sorted = zero_counts.sort_values(ascending=False)
print(zero_counts_sorted)
